# %%
# %%time
import gc
import torch
#del tensor_name
gc.collect()
torch.cuda.empty_cache()
# !pip install opencv-python
# !apt-get update && apt-get install -y libgl1-mesa-glx
# !pip install -U scikit-learn
# !pip install seaborn
# import os
# os.environ['CUDA_LAUNCH_BLOCKING'] = "1"
#!export PYTORCH_CUDA_ALLOC_CONF="max_split_size_mb=16"


# %run MultiClassifier.ipynb
torch.cuda.empty_cache()
#torch.cuda.memory_summary(device=None, abbreviated=False)

#base_data_path=''
base_data_path='datasets/CBIS-DDSM/'

dataset_path = base_data_path + 'full_256'
class_labels = ['cancer', 'not_cancer']
cf = MultiClassifier("efficientnet_v2_s", dataset_path, class_labels, "dice", 32, 2e-4, 1e-4, 12,5, 50, 4, True, True) 
print(f'Testing performance ')
print('########################################################################')

print('Loading model...') 
cf.load_model() 
cf.load_data() 


cf.show_images(DataSet.ALL)
cf.show_images(DataSet.TRAIN)
cf.show_images(DataSet.TEST)
# Out:
# 1024_13_no_preprocessing_channel_check
# Testing performance
# ########################################################################
# Loading model...
# load_model efficientnet_v2_s
# img_crop_size 220
# Data loading finished Elapsed time: 0.03 seconds
# CPU times: total: 3.34 s
# Wall time: 1.5 s

# %%
#cf.load_data()
cf.train()
#cf.train_grid(check_point=False)

# %%
#
# full  1024_12_no_preprocessing_channel_check
# MultiClassifier("resnext101_32x8d", dataset_path, class_labels, "dice", 32, 2e-4, 1e-4, 12,5, 50, 4, True, True) 
cf.self_val_model_matrix('test') 
cf.self_val_model_matrix('val')

# %%
#
# full  1024_12_no_preprocessing_channel_check
# MultiClassifier("efficientnet_b5", dataset_path, class_labels, "dice", 32, 2e-4, 1e-4, 12,5, 50, 4, True, True) 
cf.self_val_model_matrix('test') 
cf.self_val_model_matrix('val')
# Out:
# Testing  test data...
# ########################################
# ########################################
# Test Accuracy: 71.54%
# Overall Accuracy: 71.54%
# AUC-ROC: 0.77
#               precision    recall  f1-score   support
#
#       cancer       0.72      0.71      0.71       260
#   not_cancer       0.71      0.72      0.72       260
#
#     accuracy                           0.72       520
#    macro avg       0.72      0.72      0.72       520
# weighted avg       0.72      0.72      0.72       520
# Testing  val data...
# ########################################
# ########################################
# Val Accuracy: 77.39%
# Overall Accuracy: 77.39%
# AUC-ROC: 0.85
#               precision    recall  f1-score   support
#
#       cancer       0.76      0.77      0.76       315
#   not_cancer       0.79      0.78      0.78       344
#
#     accuracy                           0.77       659
#    macro avg       0.77      0.77      0.77       659
# ...

# %%
# full  1024_12_no_preprocessing_channel_check
# MultiClassifier("resnet50", dataset_path, class_labels, "dice", 32, 2e-4, 1e-4, 12,5, 50, 4, True, True) 
cf.self_val_model_matrix('test') 
cf.self_val_model_matrix('val')
# Out:
# Testing  test data...
# ########################################
# ########################################
# Test Accuracy: 69.42%
# Overall Accuracy: 69.42%
# AUC-ROC: 0.75
#               precision    recall  f1-score   support
#
#       cancer       0.68      0.73      0.71       260
#   not_cancer       0.71      0.65      0.68       260
#
#     accuracy                           0.69       520
#    macro avg       0.70      0.69      0.69       520
# weighted avg       0.70      0.69      0.69       520
# Testing  val data...
# ########################################
# ########################################
# Val Accuracy: 78.15%
# Overall Accuracy: 78.15%
# AUC-ROC: 0.85
#               precision    recall  f1-score   support
#
#       cancer       0.74      0.83      0.78       315
#   not_cancer       0.82      0.74      0.78       344
#
#     accuracy                           0.78       659
#    macro avg       0.78      0.78      0.78       659
# ...

# %%
# full  1024_12_no_preprocessing_channel_check
# MultiClassifier("resnet152", dataset_path, class_labels, "dice", 32, 2e-4, 1e-4, 12,5, 50, 4, True, True) 
cf.self_val_model_matrix('test') 
cf.self_val_model_matrix('val')
# Out:
# Testing  test data...
# ########################################
# ########################################
# Test Accuracy: 69.42%
# Overall Accuracy: 69.42%
# AUC-ROC: 0.77
#               precision    recall  f1-score   support
#
#       cancer       0.67      0.76      0.71       260
#   not_cancer       0.72      0.63      0.67       260
#
#     accuracy                           0.69       520
#    macro avg       0.70      0.69      0.69       520
# weighted avg       0.70      0.69      0.69       520
# Testing  val data...
# ########################################
# ########################################
# Val Accuracy: 76.33%
# Overall Accuracy: 76.33%
# AUC-ROC: 0.84
#               precision    recall  f1-score   support
#
#       cancer       0.74      0.82      0.78       329
#   not_cancer       0.80      0.71      0.75       330
#
#     accuracy                           0.76       659
#    macro avg       0.77      0.76      0.76       659
# ...

# %%
import torch

print("PyTorch Version: ", torch.__version__)
# Out:
# PyTorch Version:  2.1.0+cu121

# %%
# full  1024_11_no_preprocessing_channel_check
# MultiClassifier("efficientnet_v2_s", dataset_path, class_labels, "dice", 32, 2e-4, 1e-4, 12,5, 50, 4, True, True) 
#  3 try
cf.self_val_model_matrix('test') 
cf.self_val_model_matrix('val')
# Out:
# Testing  test data...
# ########################################
# ########################################
# Test Accuracy: 68.27%
# Overall Accuracy: 68.27%
# AUC-ROC: 0.76
#               precision    recall  f1-score   support
#
#       cancer       0.70      0.64      0.67       260
#   not_cancer       0.67      0.73      0.70       260
#
#     accuracy                           0.68       520
#    macro avg       0.68      0.68      0.68       520
# weighted avg       0.68      0.68      0.68       520
# Testing  val data...
# ########################################
# ########################################
# Val Accuracy: 79.82%
# Overall Accuracy: 79.82%
# AUC-ROC: 0.88
#               precision    recall  f1-score   support
#
#       cancer       0.82      0.76      0.79       332
#   not_cancer       0.78      0.83      0.80       327
#
#     accuracy                           0.80       659
#    macro avg       0.80      0.80      0.80       659
# ...

# %%
# full  1024_11_no_preprocessing_channel_check
# MultiClassifier("efficientnet_v2_s", dataset_path, class_labels, "dice", 32, 2e-4, 1e-4, 12,5, 50, 4, True, True) 
#   2 try
cf.self_val_model_matrix('test') 
cf.self_val_model_matrix('val')
# Out:
# Testing  test data...
# ########################################
# ########################################
# Test Accuracy: 71.73%
# Overall Accuracy: 71.73%
# AUC-ROC: 0.80
#               precision    recall  f1-score   support
#
#       cancer       0.74      0.66      0.70       260
#   not_cancer       0.70      0.77      0.73       260
#
#     accuracy                           0.72       520
#    macro avg       0.72      0.72      0.72       520
# weighted avg       0.72      0.72      0.72       520
# Testing  val data...
# ########################################
# ########################################
# Val Accuracy: 81.18%
# Overall Accuracy: 81.18%
# AUC-ROC: 0.89
#               precision    recall  f1-score   support
#
#       cancer       0.84      0.78      0.81       332
#   not_cancer       0.79      0.85      0.82       327
#
#     accuracy                           0.81       659
#    macro avg       0.81      0.81      0.81       659
# ...

# %%
# full  1024_11_no_preprocessing_channel_check
# MultiClassifier("efficientnet_v2_s", dataset_path, class_labels, "dice", 32, 2e-4, 1e-4, 12,5, 50, 4, True, True) 
#   
cf.self_val_model_matrix('test') 
cf.self_val_model_matrix('val')
# Out:
# Testing  test data...
# ########################################
# ########################################
# Test Accuracy: 70.77%
# Overall Accuracy: 70.77%
# AUC-ROC: 0.77
#               precision    recall  f1-score   support
#
#       cancer       0.74      0.65      0.69       260
#   not_cancer       0.68      0.77      0.72       260
#
#     accuracy                           0.71       520
#    macro avg       0.71      0.71      0.71       520
# weighted avg       0.71      0.71      0.71       520
# Testing  val data...
# ########################################
# ########################################
# Val Accuracy: 79.82%
# Overall Accuracy: 79.82%
# AUC-ROC: 0.86
#               precision    recall  f1-score   support
#
#       cancer       0.83      0.75      0.79       332
#   not_cancer       0.77      0.85      0.81       327
#
#     accuracy                           0.80       659
#    macro avg       0.80      0.80      0.80       659
# ...

# %%
# full 102 4cf = MultiClassifier("efficientnet_v2_s", dataset_path, class_labels, "tversky", 32, 3e-4, 1e-5, 12,5, 50, 4, True, True) 
#   all preprocessing + channel check
cf.self_val_model_matrix('test') 
cf.self_val_model_matrix('val')
# Out:
# Testing  test data...
# ########################################
# ########################################
# Test Accuracy: 55.96%
# Overall Accuracy: 55.96%
# AUC-ROC: 0.58
#               precision    recall  f1-score   support
#
#       cancer       0.61      0.32      0.42       260
#   not_cancer       0.54      0.80      0.64       260
#
#     accuracy                           0.56       520
#    macro avg       0.58      0.56      0.53       520
# weighted avg       0.58      0.56      0.53       520
# Testing  val data...
# ########################################
# ########################################
# Val Accuracy: 58.27%
# Overall Accuracy: 58.27%
# AUC-ROC: 0.63
#               precision    recall  f1-score   support
#
#       cancer       0.63      0.32      0.43       317
#   not_cancer       0.57      0.82      0.67       342
#
#     accuracy                           0.58       659
#    macro avg       0.60      0.57      0.55       659
# ...

# %%
# full 1024 cf = MultiClassifier("efficientnet_v2_s", dataset_path, class_labels, "dice", 32, 2e-4, 1e-5, 12,5, 50, 4, True, True) 
#   all preprocessing
cf.self_val_model_matrix('test') 
cf.self_val_model_matrix('val')
# Out:
# Testing  test data...
# ########################################
# ########################################
# Test Accuracy: 66.15%
# Overall Accuracy: 66.15%
# AUC-ROC: 0.73
#               precision    recall  f1-score   support
#
#       cancer       0.68      0.61      0.64       260
#   not_cancer       0.65      0.72      0.68       260
#
#     accuracy                           0.66       520
#    macro avg       0.66      0.66      0.66       520
# weighted avg       0.66      0.66      0.66       520
# Testing  val data...
# ########################################
# ########################################
# Val Accuracy: 71.17%
# Overall Accuracy: 71.17%
# AUC-ROC: 0.77
#               precision    recall  f1-score   support
#
#       cancer       0.75      0.66      0.70       339
#   not_cancer       0.68      0.77      0.72       320
#
#     accuracy                           0.71       659
#    macro avg       0.71      0.71      0.71       659
# ...

# %%
# full 1024 cf = MultiClassifier("efficientnet_v2_s", dataset_path, class_labels, "dice", 32, 2e-4, 1e-5, 12,5, 50, 4, True, True) 
#   no preprocessing
cf.self_val_model_matrix('test') 
cf.self_val_model_matrix('val')
# Out:
# Testing  test data...
# ########################################
# ########################################
# Test Accuracy: 70.38%
# Overall Accuracy: 70.38%
# AUC-ROC: 0.77
#               precision    recall  f1-score   support
#
#       cancer       0.70      0.70      0.70       260
#   not_cancer       0.70      0.70      0.70       260
#
#     accuracy                           0.70       520
#    macro avg       0.70      0.70      0.70       520
# weighted avg       0.70      0.70      0.70       520
# Testing  val data...
# ########################################
# ########################################
# Val Accuracy: 79.51%
# Overall Accuracy: 79.51%
# AUC-ROC: 0.86
#               precision    recall  f1-score   support
#
#       cancer       0.82      0.77      0.80       340
#   not_cancer       0.77      0.82      0.80       319
#
#     accuracy                           0.80       659
#    macro avg       0.80      0.80      0.80       659
# ...

# %%
# full 1024 cf = MultiClassifier("efficientnet_v2_s", dataset_path, class_labels, "dice", 32, 2e-4, 1e-5, 12,5, 50, 4, True, True) 
# enhance_contrast_using_clahe img_crop 적용
cf.self_val_model_matrix('test') 
cf.self_val_model_matrix('val')
# Out:
# Testing  test data...
# ########################################
# ########################################
# Test Accuracy: 68.65%
# Overall Accuracy: 68.65%
#               precision    recall  f1-score   support
#
#       cancer       0.65      0.82      0.72       260
#   not_cancer       0.75      0.56      0.64       260
#
#     accuracy                           0.69       520
#    macro avg       0.70      0.69      0.68       520
# weighted avg       0.70      0.69      0.68       520
# Testing  val data...
# ########################################
# ########################################
# Val Accuracy: 73.60%
# Overall Accuracy: 73.60%
#               precision    recall  f1-score   support
#
#       cancer       0.70      0.82      0.75       323
#   not_cancer       0.79      0.65      0.72       336
#
#     accuracy                           0.74       659
#    macro avg       0.74      0.74      0.73       659
# weighted avg       0.74      0.74      0.73       659

# %%
# full 1024 cf = MultiClassifier("efficientnet_v2_s", dataset_path, class_labels, "dice", 32, 2e-4, 1e-5, 12,5, 50, 4, True, True) 
# segment_and_visualize_transform img_crop 적용
cf.self_val_model_matrix('test') 
cf.self_val_model_matrix('val')
# Out:
# Testing  test data...
# ########################################
# ########################################
# Test Accuracy: 69.62%
# Overall Accuracy: 69.62%
#               precision    recall  f1-score   support
#
#       cancer       0.73      0.62      0.67       260
#   not_cancer       0.67      0.78      0.72       260
#
#     accuracy                           0.70       520
#    macro avg       0.70      0.70      0.69       520
# weighted avg       0.70      0.70      0.69       520
# Testing  val data...
# ########################################
# ########################################
# Val Accuracy: 76.18%
# Overall Accuracy: 76.18%
#               precision    recall  f1-score   support
#
#       cancer       0.79      0.72      0.76       338
#   not_cancer       0.73      0.80      0.77       321
#
#     accuracy                           0.76       659
#    macro avg       0.76      0.76      0.76       659
# weighted avg       0.76      0.76      0.76       659

# %%
# full 512 cf = MultiClassifier("efficientnet_v2_s", dataset_path, class_labels, "dice", 32, 2e-4, 1e-5, 12,5, 50, 4, True, True) 
cf.self_val_model_matrix('test') 
cf.self_val_model_matrix('val')
# Out:
# Testing  test data...
# ########################################
# ########################################
# Test Accuracy: 62.31%
# Overall Accuracy: 62.31%
#               precision    recall  f1-score   support
#
#       cancer       0.61      0.67      0.64       260
#   not_cancer       0.64      0.58      0.60       260
#
#     accuracy                           0.62       520
#    macro avg       0.62      0.62      0.62       520
# weighted avg       0.62      0.62      0.62       520
# Testing  val data...
# ########################################
# ########################################
# Val Accuracy: 66.77%
# Overall Accuracy: 66.77%
#               precision    recall  f1-score   support
#
#       cancer       0.68      0.69      0.68       344
#   not_cancer       0.65      0.65      0.65       315
#
#     accuracy                           0.67       659
#    macro avg       0.67      0.67      0.67       659
# weighted avg       0.67      0.67      0.67       659

# %%
# full 256 ccf = MultiClassifier("efficientnet_v2_s", dataset_path, class_labels, "dice", 32, 2e-4, 1e-5, 12,5, 50, 4, True, True) 
cf.self_val_model_matrix('test') 
cf.self_val_model_matrix('val')
# Out:
# Testing  test data...
# ########################################
# ########################################
# Test Accuracy: 57.31%
# Overall Accuracy: 57.31%
#               precision    recall  f1-score   support
#
#       cancer       0.56      0.68      0.62       260
#   not_cancer       0.59      0.46      0.52       260
#
#     accuracy                           0.57       520
#    macro avg       0.58      0.57      0.57       520
# weighted avg       0.58      0.57      0.57       520
# Testing  val data...
# ########################################
# ########################################
# Val Accuracy: 59.79%
# Overall Accuracy: 59.79%
#               precision    recall  f1-score   support
#
#       cancer       0.60      0.66      0.63       336
#   not_cancer       0.60      0.53      0.56       323
#
#     accuracy                           0.60       659
#    macro avg       0.60      0.60      0.60       659
# weighted avg       0.60      0.60      0.60       659

# %%
# full 4096 cf = MultiClassifier("efficientnet_v2_s", dataset_path, class_labels, "dice", 16, 2e-4, 1e-5, 12,5, 50, 4, True, True) 
cf.self_val_model_matrix('test') 
cf.self_val_model_matrix('val')
# Out:
# Testing  test data...
# ########################################
# ########################################
# Test Accuracy: 51.92%
# Overall Accuracy: 51.92%
#               precision    recall  f1-score   support
#
#       cancer       0.51      0.84      0.64       260
#   not_cancer       0.55      0.20      0.29       260
#
#     accuracy                           0.52       520
#    macro avg       0.53      0.52      0.46       520
# weighted avg       0.53      0.52      0.46       520
# Testing  val data...
# ########################################
# ########################################
# Val Accuracy: 55.99%
# Overall Accuracy: 55.99%
#               precision    recall  f1-score   support
#
#       cancer       0.52      0.83      0.64       314
#   not_cancer       0.67      0.31      0.42       345
#
#     accuracy                           0.56       659
#    macro avg       0.60      0.57      0.53       659
# weighted avg       0.60      0.56      0.53       659

# %%
# full 2048 cf = MultiClassifier("efficientnet_v2_s", dataset_path, class_labels, "dice", 16, 2e-4, 1e-5, 12,5, 50, 4, True, True) 
cf.self_val_model_matrix('test') 
cf.self_val_model_matrix('val')
# Out:
# Testing  test data...
# ########################################
# ########################################
# Test Accuracy: 62.87%
# Overall Accuracy: 62.87%
#               precision    recall  f1-score   support
#
#       cancer       0.79      0.12      0.20       260
#   not_cancer       0.62      0.98      0.76       381
#
#     accuracy                           0.63       641
#    macro avg       0.70      0.55      0.48       641
# weighted avg       0.69      0.63      0.53       641
# Testing  val data...
# ########################################
# ########################################
# Val Accuracy: 55.54%
# Overall Accuracy: 55.54%
#               precision    recall  f1-score   support
#
#       cancer       0.81      0.12      0.21       322
#   not_cancer       0.54      0.97      0.69       337
#
#     accuracy                           0.56       659
#    macro avg       0.67      0.55      0.45       659
# weighted avg       0.67      0.56      0.45       659

# %%
# full 1024 cf = MultiClassifier("efficientnet_v2_s", dataset_path, class_labels, "dice", 32, 2e-4, 1e-5, 12,5, 50, 4, True, True) 
cf.self_val_model_matrix('test') 
cf.self_val_model_matrix('val')
# Out:
# Testing  test data...
# ########################################
# ########################################
# Test Accuracy: 67.55%
# Overall Accuracy: 67.55%
#               precision    recall  f1-score   support
#
#       cancer       0.58      0.70      0.64       260
#   not_cancer       0.76      0.66      0.71       381
#
#     accuracy                           0.68       641
#    macro avg       0.67      0.68      0.67       641
# weighted avg       0.69      0.68      0.68       641
# Testing  val data...
# ########################################
# ########################################
# Val Accuracy: 71.17%
# Overall Accuracy: 71.17%
#               precision    recall  f1-score   support
#
#       cancer       0.71      0.71      0.71       331
#   not_cancer       0.71      0.71      0.71       328
#
#     accuracy                           0.71       659
#    macro avg       0.71      0.71      0.71       659
# weighted avg       0.71      0.71      0.71       659
